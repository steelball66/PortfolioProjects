# %%
pip install --upgrade google-api-python-client
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-core 1.7.1 requires google-api-core<2.0.0dev,>=1.21.0, but you have google-api-core 2.8.2 which is incompatible.
#   Using cached google_api_python_client-2.55.0-py2.py3-none-any.whl (8.8 MB)
# ...
#   Using cached httplib2-0.20.4-py3-none-any.whl (96 kB)
# ...
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# ...
#   Using cached google_api_core-2.8.2-py3-none-any.whl (114 kB)
# ...
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached googleapis_common_protos-1.56.4-py2.py3-none-any.whl (211 kB)
# ...
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.53.0
#     Uninstalling googleapis-common-protos-1.53.0:
#       Successfully uninstalled googleapis-common-protos-1.53.0
# ...

# %%
pip install -U rdflib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
import datetime
import calendar
import numpy as np

# Data Viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
api_key = 'AIzaSyAMXw8Oe05FO8ww0j9xnFm8OAY1_UGK__o'

# %%
channel_ids = ['UCxcTeAKWJca6XyJ37_ZoKIQ']

# %%
# Get credentials and create an API client

api_service_name = "youtube"
api_version = "v3"
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_id):
    all_data = []      

    request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id= ','.join(channel_ids),
    
    )
    response = request.execute()

    for item in response['items']:
        data  = {'channelName': item['snippet']['title'],
                 'subscribers': item['statistics']['subscriberCount'],
                 'views': item['statistics']['viewCount'],
                 'totalvideos': item['statistics']['videoCount'],
                 'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
                }
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_id)

# %%
channel_stats
# Out:
#            channelName subscribers       views totalvideos  \
# 0  The Pat McAfee Show     1900000  1160054416        5081
#
#                  playlistId
# 0  UUxcTeAKWJca6XyJ37_ZoKIQ

# %%
playlist_id = 'UUxcTeAKWJca6XyJ37_ZoKIQ'

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId="UUxcTeAKWJca6XyJ37_ZoKIQ",
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId="UUxcTeAKWJca6XyJ37_ZoKIQ",
            maxResults = 50,
            pageToken = next_page_token)
        response = request.execute()
    
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        
        next_page_token = response.get('nextPageToken')
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
def get_video_details(youtube, video_ids):
    
    all_video_info = []
    
    for i in range (0, len(video_ids), 50): 
        request = youtube.videos().list(
            part="snippet,contentDetails, statistics, liveStreamingDetails",
            id = video_ids[i:i+50]
        )
        response = request.execute()
        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', ' description', ' tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails':['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in  stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None
            all_video_info.append(video_info)
                
    return pd.DataFrame(all_video_info)
# Out:
# 5081

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#          video_id channelTitel  \
# 0     xS5TxzB5ZLs         None
# 1     mUVeOgamWR8         None
# 2     YukD1XAaSsg         None
# 3     IYISky9OM_I         None
# 4     YcgSAiU6LMg         None
# ...           ...          ...
# 5076  xQvtrmVVONw         None
# 5077  a4Db3L-9JTc         None
# 5078  tLVL_gbk8ng         None
# 5079  oWFVq7K8O00         None
# 5080  10cu4f3QsXM         None
#
#                                                   title  description  tags  \
# 0     Pat McAfee Show's Toxic Table & AJ Hawk's Most...         None  None
# 1     Jason Kelce Trolls NFL's Guardian Caps, Wears ...         None  None
# 2     DK Metcalf & Seahawks Agree To MASSIVE 3 Year,...         None  None
# 3     Kyler Murray's Controversial 4 Hour Study Clau...         None  None
# 4          The Pat McAfee Show | Friday July 29th, 2022         None  None
# ...                                                 ...          ...   ...
# ...

# %%
video_df1=pd.DataFrame(video_df)

# %%
new_df = pd.DataFrame(video_df1['publishedAt'].str[:-10])

# %%
video_df1.update(new_df)

# %%
video_df1['publishedAt'] = pd.to_datetime(video_df1['publishedAt'])

# %%
video_df1['Year']=pd.DatetimeIndex(video_df1['publishedAt']).year

# %%
video_df1['Month']=pd.DatetimeIndex(video_df1['publishedAt']).month

# %%
video_df1['channelTitel'] = "Pat Mcafee"

# %%
video_df1
# Out:
#          video_id channelTitel  \
# 0     xS5TxzB5ZLs   Pat Mcafee
# 1     mUVeOgamWR8   Pat Mcafee
# 2     YukD1XAaSsg   Pat Mcafee
# 3     IYISky9OM_I   Pat Mcafee
# 4     YcgSAiU6LMg   Pat Mcafee
# ...           ...          ...
# 5076  xQvtrmVVONw   Pat Mcafee
# 5077  a4Db3L-9JTc   Pat Mcafee
# 5078  tLVL_gbk8ng   Pat Mcafee
# 5079  oWFVq7K8O00   Pat Mcafee
# 5080  10cu4f3QsXM   Pat Mcafee
#
#                                                   title  description  tags  \
# 0     Pat McAfee Show's Toxic Table & AJ Hawk's Most...         None  None
# 1     Jason Kelce Trolls NFL's Guardian Caps, Wears ...         None  None
# 2     DK Metcalf & Seahawks Agree To MASSIVE 3 Year,...         None  None
# 3     Kyler Murray's Controversial 4 Hour Study Clau...         None  None
# 4          The Pat McAfee Show | Friday July 29th, 2022         None  None
# ...                                                 ...          ...   ...
# ...

# %%
video_df1
# Out:
#          video_id channelTitel  \
# 0     xS5TxzB5ZLs         None
# 1     mUVeOgamWR8         None
# 2     YukD1XAaSsg         None
# 3     IYISky9OM_I         None
# 4     YcgSAiU6LMg         None
# ...           ...          ...
# 5076  xQvtrmVVONw         None
# 5077  a4Db3L-9JTc         None
# 5078  tLVL_gbk8ng         None
# 5079  oWFVq7K8O00         None
# 5080  10cu4f3QsXM         None
#
#                                                   title  description  tags  \
# 0     Pat McAfee Show's Toxic Table & AJ Hawk's Most...         None  None
# 1     Jason Kelce Trolls NFL's Guardian Caps, Wears ...         None  None
# 2     DK Metcalf & Seahawks Agree To MASSIVE 3 Year,...         None  None
# 3     Kyler Murray's Controversial 4 Hour Study Clau...         None  None
# 4          The Pat McAfee Show | Friday July 29th, 2022         None  None
# ...                                                 ...          ...   ...
# ...

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
#convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df.to_csv('PMI_youtube_api.csv', index = False)

# %%
    request = youtube.channels().list(
        part="snippet,contentDetails, statistics"
    )
    response = request.execute()

    print(response)
    
    def get_video_details(youtube, video_ids):
    
    all_video_info = []
    
    for i in range (0, len(video_ids), 50): 
        request = youtube.videos().list(
            part="snippet,contentDetails, statistics, liveStreamingDetails",
            id = video_ids[i:i+50]
        )
        response = request.execute()
        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', ' description', ' tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails':['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in  stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None
            all_video_info.append(video_info)
                
    return pd.DataFrame(all_video_info)

# %%
## BEST Performing videos

sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.barplot(x='title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:15])
font= sns.set(font_scale = 0)
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)+ 'k'))

# %%
## WORST performing Videos
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.barplot(x='title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:15])
font= sns.set(font_scale = 0)
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)+ 'k'))

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.violinplot(x= 'channelTitel', y= 'viewCount', data = video_df1)
plot = ax.set_xticklabels(ax.get_xticklabels())
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)))

# %%
video_df["channelTitel"].replace({"Pat Mcafee":None}, inplace=True)

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitel       object
# title              object
#  description       object
#  tags              object
# publishedAt        object
# viewCount         float64
# likeCount         float64
# favouriteCount    float64
# commentCount      float64
# duration           object
# definition         object
# caption            object
# durationSecs      float64
# dtype: object

# %%
sns.set(rc = {'figure.figsize':(15,8)})
like_rate = video_df.eval("likeCount / viewCount * 100").rename("like_rate")
fig = plt.figure()
ax = sns.scatterplot( data = video_df, x = 'likeCount', y= 'viewCount', hue=like_rate)
plot = ax.set_xticklabels(ax.get_xticklabels())
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)))
# Out:
# C:\Users\Devin\AppData\Local\Temp\ipykernel_5996\1756192939.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot = ax.set_xticklabels(ax.get_xticklabels())

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax=video_df1.groupby('Year').viewCount.sum().plot(kind='bar')
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)))

# %%
pvt = pd.pivot_table(video_df1, columns=['Year'], index = ['Month'], aggfunc='sum', values = 'viewCount')
pvt
# Out:
# Year        2017       2018        2019        2020        2021        2022
# Month
# 1            NaN    27466.0   7294627.0  26589771.0  47932617.0  45112435.0
# 2            NaN    15894.0   2257631.0  37054977.0  40760476.0  31418632.0
# 3            NaN        NaN   3324322.0  28970098.0  40913061.0  44304090.0
# 4            NaN        NaN   6557118.0  40433548.0  35294541.0  33610155.0
# 5            NaN   347262.0   3226398.0  38728731.0  33853641.0  29331992.0
# 6            NaN   268774.0   4412290.0  30158261.0  25150176.0  29527488.0
# 7            NaN        NaN   3357697.0  32143867.0  27151684.0  19270016.0
# 8            NaN   385205.0   1545998.0  16733964.0  32907607.0         NaN
# 9       476237.0   615629.0  17346418.0  32063910.0  30691589.0         NaN
# 10      275575.0  8211261.0  36965758.0  23691490.0  33870250.0         NaN
# 11     9836893.0   933376.0  17509548.0  24430262.0  33087711.0         NaN
# ...

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax=pvt.plot(subplots= False, use_index= True)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x)))
